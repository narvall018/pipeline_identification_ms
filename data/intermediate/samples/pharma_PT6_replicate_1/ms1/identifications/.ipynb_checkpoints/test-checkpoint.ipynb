# %%
import pandas as pd

# %%
best = pd.read_parquet("./all_matches.parquet")
best
# Out:
#          peak_mz    peak_rt  peak_dt  peak_intensity    peak_ccs  \
# 1321  748.484131  10.576015    9.230     2162.216821  268.790195
# 29    429.240601  10.032334    6.745    16014.357143  217.363687
# 123   291.146271   4.575117    5.325     8100.245030  186.023200
# 1778  233.024200  10.132663    4.260     1326.231670  160.164851
# 2705  172.133453   3.655198    3.621      156.000000  145.175202
# ...          ...        ...      ...             ...         ...
# 2840  258.086700   6.028228    4.473      156.000000  165.018565
# 2700  296.023010  13.310159    4.615      169.483768  167.707719
# 2522  368.136261   8.361840    5.680      452.192490  193.065095
# 2838  258.086700   6.028228    4.473      156.000000  165.018565
# 2676  327.174072   8.712983    5.680      172.000000  193.917843
#
#                                              match_name match_adduct  \
# 1321                                     Clarithromycin       [M+H]+
# ...

# %%
best.head(30)
# Out:
#          peak_mz    peak_rt  peak_dt  peak_intensity    peak_ccs  \
# 1321  748.484131  10.576015    9.230     2162.216821  268.790195
# 29    429.240601  10.032334    6.745    16014.357143  217.363687
# 123   291.146271   4.575117    5.325     8100.245030  186.023200
# 1778  233.024200  10.132663    4.260     1326.231670  160.164851
# 2705  172.133453   3.655198    3.621      156.000000  145.175202
# 1014  195.087982   4.014962    3.621     2455.000000  143.974843
# 467   254.059082   6.053823    4.544     2994.437128  167.027837
# 2005  251.059143   3.177614    4.331      969.744371  161.454421
# 2494  335.105804   8.345116    5.680      909.645823  193.736760
# 2508  435.276855   9.992132    6.674      880.552694  215.623920
# 37    370.180450   4.901165    6.248    10804.698674  206.723866
# 1884  255.101639  10.994038    4.899     1313.920620  176.277933
# 424   237.101303   8.972151    4.260     3078.626831  160.017004
# ...

# %%
caffeine = best[best['match_name']== 'Caffeine']

# %%
caffeine
# Out:
#          peak_mz   peak_rt  peak_dt  peak_intensity    peak_ccs match_name  \
# 1014  195.087982  4.014962    3.621          2455.0  143.974843   Caffeine
#
#      match_adduct                match_smiles  match_mz  mz_error_ppm  ...  \
# 1014       [M+H]+  Cn1c(=O)c2c(ncn2C)n(C)c1=O  195.0882     -1.116532  ...
#
#           molecule_id                                  individual_scores  \
# 1014  Caffeine_[M+H]+  {'ccs': 0.4870894157485838, 'mz': 0.7766935513...
#
#       global_score  ccs_source  rt_source  confidence_level  \
# 1014      0.700217         exp        obs                 1
#
#                      confidence_reason  \
# 1014  Match parfait (CCS exp + RT obs)
#
#                                            peaks_mz_ms2  \
# 1014  [138.066, 138.065, 195.088, 195.086, 138.068, ...
#
#                                  peaks_intensities_ms2  ms2_similarity_score
# 1014  [999, 782, 540, 440, 413, 318, 131, 129, 98, 93]                   0.0
#
# [1 rows x 27 columns]
