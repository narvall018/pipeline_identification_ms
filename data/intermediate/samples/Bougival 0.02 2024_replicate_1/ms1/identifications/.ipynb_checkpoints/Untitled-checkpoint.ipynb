# %%
import pandas as pd

# %%
best = pd.read_parquet("./all_matches.parquet")
best
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 best = pd.read_parquet("./all_matches.parquet")
#       2 best
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/io/parquet.py:509, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, **kwargs)
#     506     use_nullable_dtypes = False
#     507 check_dtype_backend(dtype_backend)
# --> 509 return impl.read(
#     510     path,
#     511     columns=columns,
#     512     storage_options=storage_options,
#     513     use_nullable_dtypes=use_nullable_dtypes,
#     514     dtype_backend=dtype_backend,
#     515     **kwargs,
#     516 )
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/io/parquet.py:220, in PyArrowImpl.read(self, path, columns, use_nullable_dtypes, dtype_backend, storage_options, **kwargs)
#     217 if manager == "array":
# ...

# %%
filtered_data = best[best["match_name"] == "Dexamethasone"]
filtered_data
# Out:
#       peak_mz   peak_rt    peak_ccs     match_name match_adduct  match_mz  \
# 0  393.209106  4.776275  192.629338  Dexamethasone       [M+H]+  393.2077
#
#    mz_error_ppm  match_ccs_exp  match_ccs_pred  ccs_error_percent  \
# 0      3.576851          187.9           189.1           2.516944
#
#    match_rt_obs  match_rt_pred  rt_error_min  \
# 0           NaN       7.162271           NaN
#
#                                    individual_scores  global_score
# 0  {'ccs': 0.685382017826992, 'mz': 0.76154327386...       0.57877

# %%
best
# Out:
#          peak_mz    peak_rt    peak_ccs  \
# 0     393.209106   4.776275  192.629338
# 1     393.209106   4.776275  192.629338
# 2     393.209106   4.776275  192.629338
# 3     393.209106   4.776275  192.629338
# 4     393.209106   4.776275  192.629338
# ...          ...        ...         ...
# 2997  247.211945  15.376166  167.257399
# 2998  247.211945  15.376166  167.257399
# 2999  247.211945  15.376166  167.257399
# 3000  247.211945  15.376166  167.257399
# 3001  429.742767  31.372196  158.049215
#
#                                              match_name match_adduct  \
# 0                                         Dexamethasone       [M+H]+
# 1                                          Spiromesifen      [M+Na]+
# 2                                   Octaethylene glycol      [M+Na]+
# 3     2-Propenoic acid, 1,3,5-triazine-2,4,6-triyltr...     [M+NH4]+
# 4     17-Hydroxypregna-4,9(11)-diene-3,20-dione 17-a...      [M+Na]+
# ...
